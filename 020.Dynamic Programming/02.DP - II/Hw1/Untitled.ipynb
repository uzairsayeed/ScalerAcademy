# %%
# RecursiveApproach + Memoization --> TopDown DP 
class Solution:
    # @param A : list of list of integers
    # @return an integer
    def calculateMinimumHP(self, a):
        r, c = len(a), len(a[0])
        dp = [[0 for j in range(c)]for i in range(r)]
        if a[r-1][c-1] >=0:
            dp[r-1][c-1] = 1
        else:
            dp[r-1][c-1] = 1 - a[r-1][c-1]
        ans = self.helperFn(a, r-1, c-1, dp, dp[r-1][c-1])
        print(dp, ans)
    
    def helperFn(self, a, i, j, dp, h):
        if i == 0 and j == 0:
            dp[i][j] = h
        
        if i == 0:
            if dp[i][j] == 0:
                x = a[i][j-1]
                if x >= h:
                    h_x = 1
                else:
                    h_x = h - x
                dp[i][j] = self.helperFn(a, i, j-1, dp, h_x)
                
        elif j == 0:
            if dp[i][j] == 0:
                y = a[i-1] [j]
                if y >= h:
                    h_y = 1
                else:
                    h_y = h - y
                dp[i][j] = self.helperFn(a, i-1, j, dp, h_y)   
        
        else:
            x, y = a[i-1][j], a[i][j-1]
            if x >= h:
                h_x = 1
            else:
                h_x = h - x
            if y >= h:
                h_y = 1
            else:
                h_y = h - y
            dp[i][j] = min(self.helperFn(a, i-1, j, dp, h_x), self.helperFn(a, i, j-1, dp, h_y))
            print(i, j, dp[i][j])
        print(dp)
        return dp[i][j]
        
o = Solution()
A = [
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100],
  [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100]
]
A1 = [

   [1, -1, 0],

   [-1, 1, -1],

   [1, 0, -1]

 ]
print(o.calculateMinimumHP(A1))
# Out:
# [[3, 0, 0], [0, 0, 0], [0, 0, 2]]
# [[3, 3, 0], [0, 0, 0], [0, 0, 2]]
# [[3, 3, 3], [0, 0, 0], [0, 0, 2]]
# [[3, 3, 3], [0, 0, 0], [0, 0, 2]]
# [[2, 3, 3], [0, 0, 0], [0, 0, 2]]
# [[2, 3, 3], [2, 0, 0], [0, 0, 2]]
# 1 1 2
# [[2, 3, 3], [2, 2, 0], [0, 0, 2]]
# 1 2 2
# [[2, 3, 3], [2, 2, 2], [0, 0, 2]]
# [[2, 3, 3], [2, 2, 2], [0, 0, 2]]
# [[2, 3, 3], [2, 2, 2], [0, 0, 2]]
# 1 1 2
# [[2, 3, 3], [2, 2, 2], [0, 0, 2]]
# [[2, 3, 3], [2, 2, 2], [0, 0, 2]]
# [[2, 3, 3], [2, 2, 2], [2, 0, 2]]
# 2 1 2
# [[2, 3, 3], [2, 2, 2], [2, 2, 2]]
# 2 2 2
# [[2, 3, 3], [2, 2, 2], [2, 2, 2]]
# [[2, 3, 3], [2, 2, 2], [2, 2, 2]] 2
# None
